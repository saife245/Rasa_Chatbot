# %%
! pip install colabcode
# Out:
# ...
#      |████████████████████████████████| 745 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 45 kB 2.6 MB/s
# ...
#      |████████████████████████████████| 8.3 MB 51.8 MB/s
# ...
#      |████████████████████████████████| 428 kB 67.7 MB/s
# ...
#      |████████████████████████████████| 397 kB 61.8 MB/s
# ...
#      |████████████████████████████████| 61 kB 7.2 MB/s
# ...
#      |████████████████████████████████| 58 kB 4.9 MB/s
# ...
#      |████████████████████████████████| 79 kB 6.1 MB/s
# ...
#      |████████████████████████████████| 53 kB 1.9 MB/s
# ...
#      |████████████████████████████████| 130 kB 61.3 MB/s
# ...
#      |████████████████████████████████| 130 kB 59.1 MB/s
# ...
#      |████████████████████████████████| 129 kB 57.8 MB/s
# ...
#      |████████████████████████████████| 125 kB 56.5 MB/s
# ...
#      |████████████████████████████████| 124 kB 66.9 MB/s
# ...
#      |████████████████████████████████| 124 kB 76.5 MB/s
# ...
#      |████████████████████████████████| 122 kB 72.8 MB/s
# ...
#      |████████████████████████████████| 122 kB 28.7 MB/s
# ...

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip -o ngrok-stable-linux-amd64.zip
# Out:
# --2022-02-18 14:54:51--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 54.161.241.46, 52.202.168.65, 18.205.222.128, ...
# Connecting to bin.equinox.io (bin.equinox.io)|54.161.241.46|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13832437 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.19M  5.53MB/s    in 2.4s
#
# 2022-02-18 14:54:54 (5.53 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13832437/13832437]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %% [markdown]
# **Step to run Colabcode**
# 1. Visit https://dashboard.ngrok.com/login  and create your account, as ngrok do mandatory to create account and use authtoken individually.
#
# You reach to the dashboard of ngrok
# ![tempsnip.png](data:image/png;base64,...)

# %% [markdown]
# Go to"2. connect your account" and copy after "ngrok authtoken" i.e. which is hide inside red mark and paste it in below line after "!./ngrok authtoken " to add your authentication token in this colab session.

# %%
# !./ngrok authtoken <your authentication token>
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# import colabcode
from colabcode import ColabCode

# run colabcode with by deafult options.
ColabCode()

ColabCode(port=10000, password="   ")

# %% [markdown]
# Run above cell.
# ![cap3.PNG](data:image/png;base64,...)
#
# In cell output you got "https" link click on it.
# then You redirected to other page.
#
# ![cap1.PNG](data:image/png;base64,...)
#
# click on "Details"
#
# ![cap2.PNG](data:image/png;base64,...)
#
# Click on "visit this Unsafe site"
#
# You reached to login page of your colabcode.
# provide password(if any) and you good to go.
